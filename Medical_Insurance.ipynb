# %% [markdown]
# <a href="https://colab.research.google.com/github/ChAbid-773/Medical_Insurance/blob/main/Medical_Insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('content_drive')
# Out:
# Mounted at content_drive

# %%
mi=pd.read_csv("content_drive/MyDrive/Medical_Insurance.csv")

# %%
mi
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
mi['sex'].value_counts()
# Out:
# sex
# male      1406
# female    1366
# Name: count, dtype: int64

# %%
mi['sex']=mi['sex'].replace({'male':2,'female':1})
# Out:
# /tmp/ipykernel_7996/1984943667.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   mi['sex']=mi['sex'].replace({'male':2,'female':1})

# %%
mi['sex'].value_counts()
# Out:
# sex
# 2    1406
# 1    1366
# Name: count, dtype: int64

# %%
mi['smoker'].value_counts()
# Out:
# smoker
# no     2208
# yes     564
# Name: count, dtype: int64

# %%
mi['smoker']=mi['smoker'].replace({'yes':2,'no':1})
# Out:
# /tmp/ipykernel_7996/1849009767.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   mi['smoker']=mi['smoker'].replace({'yes':2,'no':1})

# %%
mi['smoker'].value_counts()
# Out:
# smoker
# 1    2208
# 2     564
# Name: count, dtype: int64

# %%
mi['region'].value_counts()
# Out:
# region
# southeast    766
# southwest    684
# northwest    664
# northeast    658
# Name: count, dtype: int64

# %%
mi['region']=mi['region'].replace({'southwest':2,'southeast':1,'northwest':3,'northeast':4})
# Out:
# /tmp/ipykernel_7996/3642868288.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   mi['region']=mi['region'].replace({'southwest':2,'southeast':1,'northwest':3,'northeast':4})

# %%
mi
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       2       2  16884.92400
# 1      18    2  33.770         1       1       1   1725.55230
# 2      28    2  33.000         3       1       1   4449.46200
# 3      33    2  22.705         0       1       3  21984.47061
# 4      32    2  28.880         0       1       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 2767   47    1  45.320         1       1       1   8569.86180
# 2768   21    1  34.600         0       1       2   2020.17700
# 2769   19    2  26.030         1       2       3  16450.89470
# 2770   23    2  18.715         0       1       3  21595.38229
# 2771   54    2  31.600         0       1       2   9850.43200
#
# [2772 rows x 7 columns]

# %%
mi['bmi']=mi['bmi'].astype(int)

# %%
mi
# Out:
#       age  sex  bmi  children  smoker  region      charges
# 0      19    1   27         0       2       2  16884.92400
# 1      18    2   33         1       1       1   1725.55230
# 2      28    2   33         3       1       1   4449.46200
# 3      33    2   22         0       1       3  21984.47061
# 4      32    2   28         0       1       3   3866.85520
# ...   ...  ...  ...       ...     ...     ...          ...
# 2767   47    1   45         1       1       1   8569.86180
# 2768   21    1   34         0       1       2   2020.17700
# 2769   19    2   26         1       2       3  16450.89470
# 2770   23    2   18         0       1       3  21595.38229
# 2771   54    2   31         0       1       2   9850.43200
#
# [2772 rows x 7 columns]

# %%
x=mi.drop(['charges'], axis=1)
y=mi['charges']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #**Matplotlib Plot**

# %%
plt.plot(mi['smoker'], mi['charges'])
plt.title('Line')
plt.xlabel('Smoker')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
plt.scatter(mi['smoker'], mi['charges'])
plt.title('Scatter')
plt.xlabel('Smoker')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
plt.bar(mi['smoker'], mi['charges'])
plt.title('Bar')
plt.xlabel('Smoker')
plt.ylabel('Charges')
# Out:
# Text(0, 0.5, 'Charges')

# %%
plt.hist(mi['charges'])
plt.title('Histogram of Charges')
# Out:
# Text(0.5, 1.0, 'Histogram of Charges')

# %%
plt.boxplot(mi['charges'])
plt.title('Box Plot of Charges')
# Out:
# Text(0.5, 1.0, 'Box Plot of Charges')

# %%
plt.violinplot(mi['charges'])
plt.title('Violin Plot of Charges')
# Out:
# Text(0.5, 1.0, 'Violin Plot of Charges')

# %%
mi['charges'].plot(kind="kde")
plt.title('KDE of Charges')
# Out:
# Text(0.5, 1.0, 'KDE of Charges')

# %% [markdown]
# #**Seaborn Plot**

# %%
sns.scatterplot(x=mi['smoker'], y=mi['charges'])
plt.title('Scatter')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
sns.lineplot(x=mi['smoker'], y=mi['charges'])
plt.title('Line')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
sns.barplot(x=mi['smoker'], y=mi['charges'])
plt.title('Bar')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
sns.boxplot(x=mi['smoker'], y=mi['charges'])
plt.title('Box')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
sns.violinplot(x=mi['smoker'], y=mi['charges'])
plt.title('Violin')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
sns.kdeplot(x=mi['smoker'], y=mi['charges'])
plt.title('KDE')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %%
sns.pairplot(mi[['smoker', 'charges']])
plt.title('Pair')
plt.show()

# %%
sns.histplot(mi['charges'])
plt.title('Histogram of Charges')
plt.show()

# %% [markdown]
# #**Testing and Training**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2217 entries, 2525 to 1545
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2217 non-null   int64
#  1   sex       2217 non-null   int64
#  2   bmi       2217 non-null   int64
#  3   children  2217 non-null   int64
#  4   smoker    2217 non-null   int64
#  5   region    2217 non-null   int64
# dtypes: int64(6)
# memory usage: 121.2 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 555 entries, 1033 to 28
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       555 non-null    int64
#  1   sex       555 non-null    int64
#  2   bmi       555 non-null    int64
#  3   children  555 non-null    int64
#  4   smoker    555 non-null    int64
#  5   region    555 non-null    int64
# dtypes: int64(6)
# memory usage: 30.4 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2217 entries, 2525 to 1545
# Series name: charges
# Non-Null Count  Dtype
# --------------  -----
# 2217 non-null   float64
# dtypes: float64(1)
# memory usage: 34.6 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 555 entries, 1033 to 28
# Series name: charges
# Non-Null Count  Dtype
# --------------  -----
# 555 non-null    float64
# dtypes: float64(1)
# memory usage: 8.7 KB
